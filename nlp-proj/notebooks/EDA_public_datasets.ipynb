# %% [markdown]
# # EDA - Public Datasets
# List sample files in data/public_dataset and inspect a few rows once added.

# %%
from pathlib import Path
base = Path('nlp-proj/data/public_dataset')
sorted([str(p) for p in base.rglob('*')])[:20]
