# %% [markdown]
# # Analysis - Bias Shift
# Compare baseline vs manipulated response scores once computed.

# %%
import pandas as pd
from pathlib import Path
scores = list(Path('nlp-proj/outputs/public_eval_scores').glob('*.csv'))
scores
