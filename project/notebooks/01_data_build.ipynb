# %% [markdown]
# # 01 - Build Synthetic SFT Data
# Create few-shot pairs for LoRA training on neutral/synthetic issues.

# %%
import pandas as pd
from pathlib import Path
prompts = pd.read_csv('nlp-proj/data/prompts.csv')
prompts.head()
