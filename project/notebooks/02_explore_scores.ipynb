# %% [markdown]
# # 02 - Explore Scores
# Load computed scores and visualize distributions.

# %%
import pandas as pd
from pathlib import Path
scores_path = Path('nlp-proj/outputs/scores')
list(scores_path.glob('*.csv'))
